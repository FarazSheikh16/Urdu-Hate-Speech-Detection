# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Urdu_DDF = pd.read_excel('/content/drive/MyDrive/Datasets/Urdu Abusive Dataset.xlsx')

# %%
Urdu_DDF
# Out:
#       comment_class                                       comment_text
# 0              True                             کہ کے لے لی شام دلے کی
# 1              True  اب اگر اس نے کچھ جواب دیا تو اس کی گانڈ مار دی...
# 2              True  اب ان چوتیوں نے وہ جو کنسرٹ ہو رہا تھا وہ بھی ...
# 3              True  اب ان کی گانڈ میں ہاتھ ڈال کر انتڑیاں نکالے گا...
# 4             False                      اب تک سکی سب سے اچھی ویڈیو ہے
# ...             ...                                                ...
# 2166          False                                  یہی آخری ویڈیو ہے
# 2167           True                     یوٹیوب ایکس میں جا کر ماں چدوا
# 2168          False  یوٹیوب کے دوسرے ویڈیوز کو بھی آپ دیکھو زیادہ م...
# 2169          False                                   یوٹیوبر ہا ہا ہا
# 2170           True                                                NaN
#
# [2171 rows x 2 columns]

# %%
Urdu_Class = Urdu_DDF['comment_class'].value_counts()

# Display the number of samples per class
print(Urdu_Class)
# Out:
# True     1109
# False    1062
# Name: comment_class, dtype: int64

# %%
DF1 = Urdu_DDF[Urdu_DDF['comment_class']==True]

# %%
DF1 = DF1[['comment_text']]
DF1
# Out:
#                                            comment_text
# 0                                کہ کے لے لی شام دلے کی
# 1     اب اگر اس نے کچھ جواب دیا تو اس کی گانڈ مار دی...
# 2     اب ان چوتیوں نے وہ جو کنسرٹ ہو رہا تھا وہ بھی ...
# 3     اب ان کی گانڈ میں ہاتھ ڈال کر انتڑیاں نکالے گا...
# 6     اب تو اتنی مار دی تیری بھائی نے کہ اب تو شادی ...
# ...                                                 ...
# 2157  یہ وہ انڈین مادرچود ہے جو پیسے کما کر اپنی گان...
# 2159  یہ وہی لوگ ہیں جو مروا مروا کر ایجنٹوں سے لندن...
# 2163  یہ ویڈیو دیکھ کر سندیپ کی پھٹ جائے گی اور وہ ا...
# 2167                     یوٹیوب ایکس میں جا کر ماں چدوا
# 2170                                                NaN
#
# [1109 rows x 1 columns]

# %%
Product_RDF = pd.read_csv("/content/drive/MyDrive/Datasets/products_sentiment_urdu.csv")

# %%
Product_RDF
# Out:
#                                                 sentence sentiment
# 0      بڑھتے ہوئے آلو کے لئے ہندوستانی کسانوں پر مقدم...       neg
# 1                                           تیار لباس ہے       pos
# 2      ، نائیک ، پرامن احتجاج کے امریکی آئینی حق کی ح...       pos
# 3                              جنید زیا نے عمدہ بولنگ کی       pos
# 4           اس معاملے کو دیکھنے میں مجھے زیادہ خوشی ہوگی       pos
# ...                                                  ...       ...
# 13682           معاف کیجئے گا مجھے 980 روپے کا نقصان ہوا       neg
# 13683                        یہ بہترین انتخاب کیا گیا ہے       pos
# 13684                                   براہ کرم تفصیلات       neu
# 13685                                مدعو بونس وصول نہیں       neg
# 13686  کیا آپ نائیک سے اسٹیلتھ پیک یا اکیڈمی پیک واپس...       neu
#
# [13687 rows x 2 columns]

# %%
Product_Class = Product_RDF['sentiment'].value_counts()

# Display the number of samples per class
print(Product_Class)
# Out:
# neu    5907
# pos    4328
# neg    3452
# Name: sentiment, dtype: int64

# %%
DF2 = Product_RDF[Product_RDF['sentiment']=='neg']
DF2
# Out:
#                                                 sentence sentiment
# 0      بڑھتے ہوئے آلو کے لئے ہندوستانی کسانوں پر مقدم...       neg
# 30     میں HP پروڈکٹ کی اپنی آخری خریداری سے سخت مایو...       neg
# 32       0 کوریج اور متعدد شکایت کی لیکن کوئی فائدہ نہیں       neg
# 38     میں نے ڈھونڈا سستے معیار اور بدتمیز عملہ یہاں ...       neg
# 39                            پیٹی بہت گندی اور گھٹیا ہے       neg
# ...                                                  ...       ...
# 13673                 میں نے اس پر سبسکرائب نہیں کیا ہے!       neg
# 13679                        55 روپے کی .. بوہت مہنگی ہے       neg
# 13681  مجھے وہ لڑکا پسند نہیں ہے جسے وہ اب کمرشل کے ل...       neg
# 13682           معاف کیجئے گا مجھے 980 روپے کا نقصان ہوا       neg
# 13685                                مدعو بونس وصول نہیں       neg
#
# [3452 rows x 2 columns]

# %%
DF2 = DF2[['sentence']]
DF2
# Out:
#                                                 sentence
# 0      بڑھتے ہوئے آلو کے لئے ہندوستانی کسانوں پر مقدم...
# 30     میں HP پروڈکٹ کی اپنی آخری خریداری سے سخت مایو...
# 32       0 کوریج اور متعدد شکایت کی لیکن کوئی فائدہ نہیں
# 38     میں نے ڈھونڈا سستے معیار اور بدتمیز عملہ یہاں ...
# 39                            پیٹی بہت گندی اور گھٹیا ہے
# ...                                                  ...
# 13673                 میں نے اس پر سبسکرائب نہیں کیا ہے!
# 13679                        55 روپے کی .. بوہت مہنگی ہے
# 13681  مجھے وہ لڑکا پسند نہیں ہے جسے وہ اب کمرشل کے ل...
# 13682           معاف کیجئے گا مجھے 980 روپے کا نقصان ہوا
# 13685                                مدعو بونس وصول نہیں
#
# [3452 rows x 1 columns]

# %%
Sentiment_DDF = pd.read_excel("/content/drive/MyDrive/Datasets/data1.xlsx")

# %%
Sentiment_DDF
# Out:
#         id                                               Text Label
# 0        0  بھائی صاحب  سال سے کوئی ڈرامہ اور ٨ سال سے ١ ف...   neg
# 1        1                   پڈو تم خود ایک بڑی مزاحیہ فلم ہو   pos
# 2        2   یہ تو ہیرو ہےانکا خیال تھا کہ انڈیا انڈسٹری م...   neg
# 3        3                   مبی ہے غم کی شامپر شام ھی تو ہے    neg
# 4        4  تبصرہ بہت اچھا ہے  میرے لئے بہت مفید ثابت ہوا ...   pos
# ...    ...                                                ...   ...
# 9694  9694  مید ہے کہ انشا اللہ آج پاکستان جنوبی افریقہ سے...   pos
# 9695  9695  کیا کسی بھائی یا بہن کو کوئی لنک معلوم ہے جہاں...   neu
# 9696  9696   گوگل سے جتنے لنک مل رہے ہیں وہ سب سپیم سائٹس ہیں   neg
# 9697  9697          میں نے پاکستان کا پچھلا میچ یہاں سے دیکھا   neu
# 9698  9698                    اسوقت خواتین کا فائنل ہو رہا ہے   neu
#
# [9699 rows x 3 columns]

# %%
Sentiment_Class = Sentiment_DDF['Label'].value_counts()

# Display the number of samples per class
print(Sentiment_Class)
# Out:
# neu    3622
# pos    3527
# neg    2550
# Name: Label, dtype: int64

# %%
DF3 = Sentiment_DDF[Sentiment_DDF['Label']=='neg']
DF3
# Out:
#         id                                               Text Label
# 0        0  بھائی صاحب  سال سے کوئی ڈرامہ اور ٨ سال سے ١ ف...   neg
# 2        2   یہ تو ہیرو ہےانکا خیال تھا کہ انڈیا انڈسٹری م...   neg
# 3        3                   مبی ہے غم کی شامپر شام ھی تو ہے    neg
# 5        5  جہاں سوچ پر پہرے ہوں وہاں تخلیق مرجاتی ہے اشتہ...   neg
# 11      11  پیارے افضل کا اینڈ پہلے سے ہی صاف نظر آ رہا تھ...   neg
# ...    ...                                                ...   ...
# 9678  9678  میچ ہاتھ سے نکلتا جا رہا ہے اور ساری کمزوری بی...   neg
# 9679  9679  یونس خان تو ٹیسٹ میچ میں  بنا کر بھول ہی گیا ہ...   neg
# 9680  9680  بھائ صاحب یہ پریشر میں آگئے ہوئے ہیں‌ بس سکور ...   neg
# 9689  9689  اس میں سکاٹ لینڈ نے چار وکٹوں کے نقصان پر  اسک...   neg
# 9696  9696   گوگل سے جتنے لنک مل رہے ہیں وہ سب سپیم سائٹس ہیں   neg
#
# [2550 rows x 3 columns]

# %%
DF3 = DF3[['Text']]
DF3
# Out:
#                                                    Text
# 0     بھائی صاحب  سال سے کوئی ڈرامہ اور ٨ سال سے ١ ف...
# 2      یہ تو ہیرو ہےانکا خیال تھا کہ انڈیا انڈسٹری م...
# 3                      مبی ہے غم کی شامپر شام ھی تو ہے
# 5     جہاں سوچ پر پہرے ہوں وہاں تخلیق مرجاتی ہے اشتہ...
# 11    پیارے افضل کا اینڈ پہلے سے ہی صاف نظر آ رہا تھ...
# ...                                                 ...
# 9678  میچ ہاتھ سے نکلتا جا رہا ہے اور ساری کمزوری بی...
# 9679  یونس خان تو ٹیسٹ میچ میں  بنا کر بھول ہی گیا ہ...
# 9680  بھائ صاحب یہ پریشر میں آگئے ہوئے ہیں‌ بس سکور ...
# 9689  اس میں سکاٹ لینڈ نے چار وکٹوں کے نقصان پر  اسک...
# 9696   گوگل سے جتنے لنک مل رہے ہیں وہ سب سپیم سائٹس ہیں
#
# [2550 rows x 1 columns]

# %%
# Example for a TSV file without a header
df = pd.read_csv("/content/drive/MyDrive/Datasets/urdu-sentiment-corpus-v1.tsv", delimiter='\t', header=None)

# Set column names
df.columns = ['Tweet', 'Class']  # Replace with your actual column names

# %%
df
# Out:
#                                                   Tweet  Class
# 0                                                 Tweet  Class
# 1     میں نے ایٹم بم بنایا ھے ۔۔۔۔او بھائی ایٹم بمب ...      P
# 2     چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...      N
# 3                              ٹویٹر کا خیال کیسے آیا ؟      O
# 4     سرچ انجن گوگل کے نائب صدر نے فضا میں ، 130,000...      P
# ...                                                 ...    ...
# 996      اُس آدمی نے اِس سالار کو کافی معقول ٹپ دی ہے ۔      P
# 997   چچا غالب کی روح سے معذرت کے ساتھہم نے مانا کہ ...      P
# 998   واہ جناب واہ! اچھی رہی۔ جناب خود کو فرشتہ سمجو...      P
# 999   اسلام آباد :پی اے ٹی کا دھرنا ختم، صفائی کے کا...      P
# 1000  دنیا نے کس کا راہ وفا میں دیا ہے ساتھتم بھی چل...      P
#
# [1001 rows x 2 columns]

# %%
class_counts = df['Class'].value_counts()

# Display the number of samples per class
print(class_counts)
# Out:
# N        499
# P        480
# O         20
# Class      1
# Name: Class, dtype: int64

# %%
DF4 = df[df['Class']=='N']
DF4
# Out:
#                                                  Tweet Class
# 2    چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...     N
# 6     گندی زبان اور گٹر جیسے دماغ والے جاهل جیالے ه...     N
# 7    قاتل بھی تم مقتول بھی تم,ظالم بھی ہم اور مظلوم...     N
# 15   مؤرخ لکھے گاکہ مملکتِ خداد پر ایسا کڑا وقت بھی...     N
# 18     ابن ڈیزل ہواُکرے کوئی میرے درد کی دوا کرے کوئی      N
# ..                                                 ...   ...
# 982  اسلام آباد: ملزم کا ایک ساتھی فرار ہوگیا، کسی ...     N
# 983  ﺟﻮ PTI ﮐﮯ ﻟﻮﮒ ﮔﺎﻟﯽ ﮔﻠﻮﭺ ﮐﺮ ﺭﮨﮯ ﮨﯿﮟ ۔ ﺍﻥ ﮐﻮ 30 ...     N
# 991  انشاء جی اٹھو اب کوچ کرو، اس شہر ميں جی کو لگا...     N
# 993   پہلی بار مجھے بھی جب کسی نے انکل کہا تھا تو د...     N
# 994   چندے سے انقلاب نہیں لایا جاسکتا اور نہ بندے ا...     N
#
# [499 rows x 2 columns]

# %%
DF4 = DF4[['Tweet']]
DF4
# Out:
#                                                  Tweet
# 2    چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...
# 6     گندی زبان اور گٹر جیسے دماغ والے جاهل جیالے ه...
# 7    قاتل بھی تم مقتول بھی تم,ظالم بھی ہم اور مظلوم...
# 15   مؤرخ لکھے گاکہ مملکتِ خداد پر ایسا کڑا وقت بھی...
# 18     ابن ڈیزل ہواُکرے کوئی میرے درد کی دوا کرے کوئی
# ..                                                 ...
# 982  اسلام آباد: ملزم کا ایک ساتھی فرار ہوگیا، کسی ...
# 983  ﺟﻮ PTI ﮐﮯ ﻟﻮﮒ ﮔﺎﻟﯽ ﮔﻠﻮﭺ ﮐﺮ ﺭﮨﮯ ﮨﯿﮟ ۔ ﺍﻥ ﮐﻮ 30 ...
# 991  انشاء جی اٹھو اب کوچ کرو، اس شہر ميں جی کو لگا...
# 993   پہلی بار مجھے بھی جب کسی نے انکل کہا تھا تو د...
# 994   چندے سے انقلاب نہیں لایا جاسکتا اور نہ بندے ا...
#
# [499 rows x 1 columns]

# %%
result_series = pd.concat([DF1['comment_text'], DF2['sentence'], DF3['Text'], DF4['Tweet']], axis=0, ignore_index=True)

# %%
result_series
# Out:
# 0                                  کہ کے لے لی شام دلے کی
# 1       اب اگر اس نے کچھ جواب دیا تو اس کی گانڈ مار دی...
# 2       اب ان چوتیوں نے وہ جو کنسرٹ ہو رہا تھا وہ بھی ...
# 3       اب ان کی گانڈ میں ہاتھ ڈال کر انتڑیاں نکالے گا...
# 4       اب تو اتنی مار دی تیری بھائی نے کہ اب تو شادی ...
#                               ...
# 7605    اسلام آباد: ملزم کا ایک ساتھی فرار ہوگیا، کسی ...
# 7606    ﺟﻮ PTI ﮐﮯ ﻟﻮﮒ ﮔﺎﻟﯽ ﮔﻠﻮﭺ ﮐﺮ ﺭﮨﮯ ﮨﯿﮟ ۔ ﺍﻥ ﮐﻮ 30 ...
# 7607    انشاء جی اٹھو اب کوچ کرو، اس شہر ميں جی کو لگا...
# 7608     پہلی بار مجھے بھی جب کسی نے انکل کہا تھا تو د...
# 7609     چندے سے انقلاب نہیں لایا جاسکتا اور نہ بندے ا...
# Length: 7610, dtype: object

# %%
# Specify the Excel file path
#excel_file_path = '/path/to/your/output/file.xlsx'

# Write the Series to Excel
result_series.to_excel('output.xlsx', index=False, header=['sentences'])
